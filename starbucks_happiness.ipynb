# %% [markdown]
# # Import Dependencies

# %%
import pandas as pd
import pycountry
from sqlalchemy import create_engine
from getpass import getpass

# %% [markdown]
# # Starbucks Data -Dataset 1

# %%
starbucks_raw = "Resources\starbucks.csv"
starbucks_df = pd.read_csv(starbucks_raw)
starbucks_df.head()
# Out:
#        Brand  Store Number                Store Name Ownership Type  \
# 0  Starbucks  47370-257954             Meritxell, 96       Licensed
# 1  Starbucks  47089-256771                 Dana Mall       Licensed
# 2  Starbucks  22126-218024                Twofour 54       Licensed
# 3  Starbucks  17127-178586              Al Ain Tower       Licensed
# 4  Starbucks  17688-182164  Dalma Mall, Ground Floor       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 2                  Al Salam Street         Abu Dhabi             AZ      AE
# 3  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
# 4             Dalma Mall, Mussafah         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# ...

# %% [markdown]
# # Clean Starbucks dataset

# %% [markdown]
# ## Eliminate unnecessary columns

# %%
test_df = starbucks_df[['Store Number','Brand', 'Store Name','Ownership Type','Street Address','City','State/Province','Country']]
test.head()
# Out:
#    Store Number      Brand                Store Name Ownership Type  \
# 0  47370-257954  Starbucks             Meritxell, 96       Licensed
# 1  47089-256771  Starbucks                 Dana Mall       Licensed
# 2  22126-218024  Starbucks                Twofour 54       Licensed
# 3  17127-178586  Starbucks              Al Ain Tower       Licensed
# 4  17688-182164  Starbucks  Dalma Mall, Ground Floor       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 2                  Al Salam Street         Abu Dhabi             AZ      AE
# 3  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
# 4             Dalma Mall, Mussafah         Abu Dhabi             AZ      AE
#
#               country_2
# 0               Andorra
# 1  United Arab Emirates
# ...

# %%
# pycountry.countries.lookup('AD')

pycountry.countries.lookup(test_df['Country'][0])
# Out:
# Country(alpha_2='AD', alpha_3='AND', name='Andorra', numeric='020', official_name='Principality of Andorra')

# %%
pycountry.countries.get(alpha_2 = 'AD').name
# Out:
# 'Andorra'

# %%
df = test_df

list_alpha_2 = [i.alpha_2 for i in list(pycountry.countries)]

def country_flag(df):
    if (len(df['Country'])==2 and df['Country'] in list_alpha_2):
        return pycountry.countries.get(alpha_2=df['Country']).name
    else:
        inv_count += 1
        return 'Invalid Code'

test_df['country_2']=test_df.apply(country_flag, axis = 1)

test_df.head()
# Out:
# C:\Users\Peter\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#    Store Number      Brand                Store Name Ownership Type  \
# 0  47370-257954  Starbucks             Meritxell, 96       Licensed
# 1  47089-256771  Starbucks                 Dana Mall       Licensed
# 2  22126-218024  Starbucks                Twofour 54       Licensed
# 3  17127-178586  Starbucks              Al Ain Tower       Licensed
# 4  17688-182164  Starbucks  Dalma Mall, Ground Floor       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# ...

# %%
starbucks_df = test_df[['Brand','Store Number', 'Store Name','Ownership Type','Street Address','City','State/Province','Country','country_2']].copy()
starbucks_df = starbucks_df.rename(columns={"Store Number":"id",
                                      "Brand":"brand",
                                      "Store Name":"store_name",
                                      "Ownership Type":"ownership_type",
                                      "Street Address":"address",
                                      "City":"city",
                                      "State/Province":"state",
                                      "country_2":"country"})

# %%
starbucks_df = starbucks_df[['id','brand', 'store_name','ownership_type','address','city','state','country']]
starbucks_df.set_index('id')

starbucks_df.head()
# starbucks_df = starbucks_df[starbucks_df['id']!='47370-257954']
# Out:
#              id      brand                store_name ownership_type  \
# 0  47370-257954  Starbucks             Meritxell, 96       Licensed
# 1  47089-256771  Starbucks                 Dana Mall       Licensed
# 2  22126-218024  Starbucks                Twofour 54       Licensed
# 3  17127-178586  Starbucks              Al Ain Tower       Licensed
# 4  17688-182164  Starbucks  Dalma Mall, Ground Floor       Licensed
#
#                            address              city state  \
# 0                Av. Meritxell, 96  Andorra la Vella     7
# 1     Sheikh Khalifa Bin Zayed St.             Ajman    AJ
# 2                  Al Salam Street         Abu Dhabi    AZ
# 3  Khaldiya Area, Abu Dhabi Island         Abu Dhabi    AZ
# 4             Dalma Mall, Mussafah         Abu Dhabi    AZ
#
#                 country
# 0               Andorra
# 1  United Arab Emirates
# 2  United Arab Emirates
# 3  United Arab Emirates
# 4  United Arab Emirates

# %%
# print(f"# unique countires: {len(starbucks['country'].unique())}")
# starbucks['country'].value_counts()
# starbucks.head()

# %%
starbucks_df[["id", "country"]]
# Out:
#                 id               country
# 0      47370257954               Andorra
# 1      47089256771  United Arab Emirates
# 2      22126218024  United Arab Emirates
# 3      17127178586  United Arab Emirates
# 4      17688182164  United Arab Emirates
# 5      18182182165  United Arab Emirates
# 6      23359229184  United Arab Emirates
# 7       3078199022  United Arab Emirates
# 8      20423205465  United Arab Emirates
# 9      20424205466  United Arab Emirates
# 10      1579122101  United Arab Emirates
# 11     32595122105  United Arab Emirates
# 12     24191236428  United Arab Emirates
# 13     24604238367  United Arab Emirates
# 14     32029110804  United Arab Emirates
# 15     29560238539  United Arab Emirates
# 16     32239100001  United Arab Emirates
# 17     31719103601  United Arab Emirates
# 18     20008200004  United Arab Emirates
# 19     32767131566  United Arab Emirates
# 20      3886141408  United Arab Emirates
# 21     29539254261  United Arab Emirates
# ...

# %% [markdown]
# # Check for Duplicate Values

# %%
starbucks_df[starbucks_df.duplicated(['id'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, brand, store_name, ownership_type, address, city, state, country]
# Index: []

# %%
# starbucks[starbucks.duplicated(['id'], keep='first')]

# %%
starbucks_df['country'].value_counts().nlargest()
# Out:
# United States         13608
# China                  2734
# Canada                 1468
# Japan                  1237
# Korea, Republic of      992
# Name: country, dtype: int64

# %%
starbucks_df['id']=[i.replace('-','') for i in starbucks_df['id']]

starbucks_df.head()
# Out:
#             id      brand                store_name ownership_type  \
# 0  47370257954  Starbucks             Meritxell, 96       Licensed
# 1  47089256771  Starbucks                 Dana Mall       Licensed
# 2  22126218024  Starbucks                Twofour 54       Licensed
# 3  17127178586  Starbucks              Al Ain Tower       Licensed
# 4  17688182164  Starbucks  Dalma Mall, Ground Floor       Licensed
#
#                            address              city state  \
# 0                Av. Meritxell, 96  Andorra la Vella     7
# 1     Sheikh Khalifa Bin Zayed St.             Ajman    AJ
# 2                  Al Salam Street         Abu Dhabi    AZ
# 3  Khaldiya Area, Abu Dhabi Island         Abu Dhabi    AZ
# 4             Dalma Mall, Mussafah         Abu Dhabi    AZ
#
#                 country
# 0               Andorra
# 1  United Arab Emirates
# 2  United Arab Emirates
# 3  United Arab Emirates
# 4  United Arab Emirates

# %% [markdown]
# # Country database

# %%
country_raw = pd.read_csv("Resources\world-happiness-report-2019.csv")
country_raw.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
country_df = country_raw[['Country (region)','Ladder']]
country_df['Ladder'].astype(int)
c.head()
# Out:
#   Country (region)  Ladder
# 0          Finland       1
# 1          Denmark       2
# 2           Norway       3
# 3          Iceland       4
# 4      Netherlands       5

# %%
country_df = country_df.rename(columns={'Country (region)':'country','Ladder':'happiness'})
country_df.set_index('country')

country_df.head()
# Out:
#        country  happiness
# 0      Finland          1
# 1      Denmark          2
# 2       Norway          3
# 3      Iceland          4
# 4  Netherlands          5

# %%
temp_merge = pd.merge(starbucks_df, country_df, left_on = "country", right_on = "country", how="left")

temp_merge[['happiness']] = temp_merge[['happiness']].fillna(value = 0)
temp_merge
# Out:
#                 id      brand                           store_name  \
# 0      47370257954  Starbucks                        Meritxell, 96
# 1      47089256771  Starbucks                            Dana Mall
# 2      22126218024  Starbucks                           Twofour 54
# 3      17127178586  Starbucks                         Al Ain Tower
# 4      17688182164  Starbucks             Dalma Mall, Ground Floor
# 5      18182182165  Starbucks                  Dalma Mall, Level 1
# 6      23359229184  Starbucks                   Debenhams Yas Mall
# 7       3078199022  Starbucks                     Khalidiya Street
# 8      20423205465  Starbucks                    Eastern Mangroves
# 9      20424205466  Starbucks                        Nation Towers
# 10      1579122101  Starbucks  HCT Abu Dhabi Women's College Block
# 11     32595122105  Starbucks          Standard Chartered Building
# 12     24191236428  Starbucks                  International Tower
# ...

# %%
temp = temp_merge[temp_merge.happiness == 0]
temp.head()
# Out:
#               id      brand                       store_name ownership_type  \
# 0    47370257954  Starbucks                    Meritxell, 96       Licensed
# 292  15476160864  Starbucks                   Paseo Herencia       Licensed
# 293   3635146029  Starbucks  Renaissance Seaport Marketplace       Licensed
# 294   3634146030  Starbucks         Renaissance Mall - Aruba       Licensed
# 344  26078242484  Starbucks                     KUALA BELAIT       Licensed
#
#                                                address              city  \
# 0                                    Av. Meritxell, 96  Andorra la Vella
# 292                           J.E. Irausquin Blvd 382A             Noord
# 293                                  L.G.Smith Blvd. 9        Oranjestad
# 294                            L.G. Smith Boulevard 82        Oranjestad
# 344  LOT 5354, KG. PANDAN KUALA BELAIT, BRUNEI DARU...            Brunei
#
#     state            country  happiness
# ...

# %%
temp['country'].unique().tolist()
# Out:
# ['Andorra',
#  'Aruba',
#  'Brunei Darussalam',
#  'Bolivia, Plurinational State of',
#  'Bahamas',
#  'Curaçao',
#  'Czechia',
#  'Korea, Republic of',
#  'Monaco',
#  'Oman',
#  'Puerto Rico',
#  'Russian Federation',
#  'Taiwan, Province of China',
#  'Viet Nam']

# %%
starbucks_df['country'] = starbucks_df['country'].replace({'Bolivia, Plurinational State of':'Bolivia',
                                                           'Czechia':'Czech Republic',
                                                           'Korea, Republic of':'South Korea',
                                                           'Russian Federation':'Russia',
                                                           'Taiwan, Province of China':'Taiwan',
                                                           'Viet Nam':'Vietnam'})

# %%
starbucks_df
# Out:
#                 id      brand                           store_name  \
# 0      47370257954  Starbucks                        Meritxell, 96
# 1      47089256771  Starbucks                            Dana Mall
# 2      22126218024  Starbucks                           Twofour 54
# 3      17127178586  Starbucks                         Al Ain Tower
# 4      17688182164  Starbucks             Dalma Mall, Ground Floor
# 5      18182182165  Starbucks                  Dalma Mall, Level 1
# 6      23359229184  Starbucks                   Debenhams Yas Mall
# 7       3078199022  Starbucks                     Khalidiya Street
# 8      20423205465  Starbucks                    Eastern Mangroves
# 9      20424205466  Starbucks                        Nation Towers
# 10      1579122101  Starbucks  HCT Abu Dhabi Women's College Block
# 11     32595122105  Starbucks          Standard Chartered Building
# 12     24191236428  Starbucks                  International Tower
# ...

# %% [markdown]
# # Connect to local database

# %%
username=input("Enter User Name    ")
# Out:
# Enter User Name    postgres

# %%
password=getpass("Enter Password :")
# Out:
# Enter Password :········

# %%
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/Starbucks_Happiness_db')
connection = engine.connect()

# %%
 engine.table_names()
# Out:
# ['starbucks', 'happiness']

# %%
starbucks_df.to_sql(name='starbucks', con = engine, if_exists='append', index=False)

# %%
country_df.to_sql(name='happiness', con=engine, if_exists='append', index=False)

# %% [markdown]
# # Confirm data has been added by querying the starbucks table

# %%
pd.read_sql_query('select * from starbucks', con=engine).head()
# Out:
#             id      brand                store_name ownership_type  \
# 0  47089256771  Starbucks                 Dana Mall       Licensed
# 1  22126218024  Starbucks                Twofour 54       Licensed
# 2  17127178586  Starbucks              Al Ain Tower       Licensed
# 3  17688182164  Starbucks  Dalma Mall, Ground Floor       Licensed
# 4  18182182165  Starbucks       Dalma Mall, Level 1       Licensed
#
#                            address       city state               country
# 0     Sheikh Khalifa Bin Zayed St.      Ajman    AJ  United Arab Emirates
# 1                  Al Salam Street  Abu Dhabi    AZ  United Arab Emirates
# 2  Khaldiya Area, Abu Dhabi Island  Abu Dhabi    AZ  United Arab Emirates
# 3             Dalma Mall, Mussafah  Abu Dhabi    AZ  United Arab Emirates
# 4             Dalma Mall, Mussafah  Abu Dhabi    AZ  United Arab Emirates

# %% [markdown]
# # Confirm data has been added by querying the happiness table

# %%
pd.read_sql_query('select * from happiness', con=engine).head()
# Out:
#    id      country  happiness
# 0   1      Finland          1
# 1   2      Denmark          2
# 2   3       Norway          3
# 3   4      Iceland          4
# 4   5  Netherlands          5
